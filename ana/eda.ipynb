# %%
import pandas as pd

# Load the datasets
patients_df = pd.read_csv('data/Patients.csv')

# Display the first few rows of the dataset
patients_df.head()
# Out:
#    PATIENTID  GENDER ETHNICITY DECEASED DEATHCAUSECODE_1A DEATHLOCATIONCODE  \
# 0   10273711       1       NaN        N               NaN               NaN
# 1   10275818       1         A        Y              K566                 4
# 2   10276182       1         A        Y              J189                 1
# 3   10277943       1         A        N               NaN               NaN
# 4   10279280       1         A        Y               C19                 4
#
#   VITALSTATUS VITALSTATUSDATE
# 0           A        5/7/2022
# 1           D      20/10/2021
# 2           D       18/7/2020
# 3           A        5/7/2022
# 4           D       31/7/2022

# %%
patients_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181241 entries, 0 to 181240
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   PATIENTID          181241 non-null  int64
#  1   GENDER             181241 non-null  int64
#  2   ETHNICITY          178646 non-null  object
#  3   DECEASED           181241 non-null  object
#  4   DEATHCAUSECODE_1A  31989 non-null   object
#  5   DEATHLOCATIONCODE  31984 non-null   object
#  6   VITALSTATUS        181241 non-null  object
#  7   VITALSTATUSDATE    181210 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 11.1+ MB

# %%
# Load the Diagnosis dataset
diagnosis_df = pd.read_csv('data/Diagnosis.csv') 

# Display the first few rows and dataset info
diagnosis_df.head()
# Out:
#    PATIENTID DIAGNOSISDATEBEST  SITE_ICD10_O2_3CHAR T_BEST N_BEST M_BEST  \
# 0   10300617         2/11/2019  C50 (Breast Cancer)      2      0     1b
# 1   10300637          5/6/2018  C50 (Breast Cancer)    NaN    NaN    NaN
# 2   10300641         26/1/2019  C50 (Breast Cancer)     1c      0      0
# 3   10300713         9/12/2017  C50 (Breast Cancer)      2      0      0
# 4   10300729         21/7/2019  C50 (Breast Cancer)      3      1      0
#
#   STAGE_BEST GRADE  AGE ER_STATUS PR_STATUS HER2_STATUS       QUINTILE_2019  \
# 0         3A    G3   46         P         P           N                   2
# 1          ?    G1   87         P       NaN           N                   4
# 2         1A    G2   87       NaN       NaN         NaN   1 - most deprived
# 3         2A    G2   74         U       NaN           N  5 - least deprived
# 4         2B    G3   71       NaN       NaN           P                   3
#
# ...

# %%
# Load the Treatment dataset
treatment_df = pd.read_csv('data/Treatment.csv')

# Display the first few rows and dataset info
treatment_df.head()
# Out:
#    ENCORE_PATIENT_ID  HEIGHT_AT_START_OF_REGIMEN  WEIGHT_AT_START_OF_REGIMEN  \
# 0           10282626                        1.60                         NaN
# 1           10291762                        1.53                       46.95
# 2           10292545                         NaN                       72.20
# 3           10293472                        1.64                       67.20
# 4           10297710                        1.57                      102.00
#
#   DATE_DECISION_TO_TREAT START_DATE_OF_REGIMEN CLINICAL_TRIAL CHEMO_RADIATION  \
# 0                    NaN             18/9/2017            NaN             NaN
# 1                    NaN              8/3/2020            NaN             NaN
# 2                    NaN             9/12/2017            NaN               N
# 3                    NaN             25/8/2017            NaN               N
# 4               2/7/2016              8/8/2016              2               N
#
#             BENCHMARK_GROUP
# ...

# %%
treatment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147805 entries, 0 to 147804
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ENCORE_PATIENT_ID           147805 non-null  int64
#  1   HEIGHT_AT_START_OF_REGIMEN  139731 non-null  float64
#  2   WEIGHT_AT_START_OF_REGIMEN  140348 non-null  float64
#  3   DATE_DECISION_TO_TREAT      137545 non-null  object
#  4   START_DATE_OF_REGIMEN       147617 non-null  object
#  5   CLINICAL_TRIAL              141739 non-null  object
#  6   CHEMO_RADIATION             109976 non-null  object
#  7   BENCHMARK_GROUP             147805 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 9.0+ MB

# %%
diagnosis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187204 entries, 0 to 187203
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   PATIENTID             187204 non-null  int64
#  1   DIAGNOSISDATEBEST     187204 non-null  object
#  2   SITE_ICD10_O2_3CHAR   187204 non-null  object
#  3   T_BEST                171382 non-null  object
#  4   N_BEST                169038 non-null  object
#  5   M_BEST                132926 non-null  object
#  6   STAGE_BEST            187203 non-null  object
#  7   GRADE                 187204 non-null  object
#  8   AGE                   187204 non-null  int64
#  9   ER_STATUS             166238 non-null  object
#  10  PR_STATUS             114933 non-null  object
#  11  HER2_STATUS           153626 non-null  object
#  12  QUINTILE_2019         187204 non-null  object
#  13  DATE_FIRST_SURGERY    158771 non-null  object
# ...

# %%
# Load the Data Dictionary
data_dict_df = pd.read_excel('data/Data_Dictionary.xlsx')

# Display the first few rows and dataset info
data_dict_df.head()
# Out:
#           Field name                              Data item Data format  \
# 0          PATIENTID               Pseudonymised patient ID     Integer
# 1             GENDER                   Person stated gender   Character
# 2          ETHNICITY                              Ethnicity   Character
# 3           DECEASED  Indicates if the Patient has deceased   Character
# 4  DEATHCAUSECODE_1A    As provided with death notification   Character
#
#                                                Notes
# 0                                                NaN
# 1  Consult z_gender in all_z_lookup_tables.csv fo...
# 2  Consult z_ethnicity in all_z_lookup_tables.csv...
# 3                                                NaN
# 4  Codes are in ICD-10 format and may be a comma-...

# %%
data_dict_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Field name   9 non-null      object
#  1   Data item    9 non-null      object
#  2   Data format  9 non-null      object
#  3   Notes        7 non-null      object
# dtypes: object(4)
# memory usage: 416.0+ bytes

# %%
# Load the Lookup Tables
lookup_tables_df = pd.read_excel('data/Lookup_Tables.xlsx')

# Display the first few rows and dataset info
lookup_tables_df.head()
# Out:
#   Code                                        Description
# 0    1                                           Hospital
# 1    2  Hospice NOS, NHS hospice / specialist palliati...
# 2    3  Voluntary hospice / specialist palliative care...
# 3    4  Other private residence (e.g. relatives home, ...
# 4    5    Care home, care home with nursing, nursing home

# %%
lookup_tables_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Code         7 non-null      object
#  1   Description  7 non-null      object
# dtypes: object(2)
# memory usage: 240.0+ bytes

# %%
# Handling Missing Values

# Patients Dataset
# Impute missing ethnicity with 'Unknown' (or drop rows if needed)
patients_df['ETHNICITY'] = patients_df['ETHNICITY'].fillna('Unknown')

# For vital status date, let's fill missing values with the most recent date from the dataset
patients_df['VITALSTATUSDATE'] = pd.to_datetime(patients_df['VITALSTATUSDATE'],
                                                 errors='coerce')
patients_df['VITALSTATUSDATE'] = patients_df['VITALSTATUSDATE'].fillna(
    patients_df['VITALSTATUSDATE'].max())

# Diagnosis Dataset
# For missing values in T_BEST, N_BEST, M_BEST, and STAGE_BEST, we'll impute using the most frequent value (mode)
diagnosis_df['T_BEST'] = diagnosis_df['T_BEST'].fillna(
    diagnosis_df['T_BEST'].mode()[0])
diagnosis_df['N_BEST'] = diagnosis_df['N_BEST'].fillna(
    diagnosis_df['N_BEST'].mode()[0])
diagnosis_df['M_BEST'] = diagnosis_df['M_BEST'].fillna(
    diagnosis_df['M_BEST'].mode()[0])
diagnosis_df['STAGE_BEST'] = diagnosis_df['STAGE_BEST'].fillna(
    diagnosis_df['STAGE_BEST'].mode()[0])

# Treatment Dataset
# Impute missing HEIGHT and WEIGHT with the mean values (or drop if necessary)
treatment_df['HEIGHT_AT_START_OF_REGIMEN'] = treatment_df['HEIGHT_AT_START_OF_REGIMEN'].fillna(treatment_df['HEIGHT_AT_START_OF_REGIMEN'].mean())
treatment_df['WEIGHT_AT_START_OF_REGIMEN'] = treatment_df['WEIGHT_AT_START_OF_REGIMEN'].fillna(treatment_df['WEIGHT_AT_START_OF_REGIMEN'].mean())

# Impute missing dates with the most recent decision date from the dataset
treatment_df['DATE_DECISION_TO_TREAT'] = pd.to_datetime(treatment_df['DATE_DECISION_TO_TREAT'], errors='coerce')
treatment_df['DATE_DECISION_TO_TREAT'] = treatment_df['DATE_DECISION_TO_TREAT'].fillna(treatment_df['DATE_DECISION_TO_TREAT'].max())

# For missing START_DATE_OF_REGIMEN, impute using the most recent date
treatment_df['START_DATE_OF_REGIMEN'] = pd.to_datetime(treatment_df['START_DATE_OF_REGIMEN'], errors='coerce')
treatment_df['START_DATE_OF_REGIMEN'] = treatment_df['START_DATE_OF_REGIMEN'].fillna(treatment_df['START_DATE_OF_REGIMEN'].max())

# Display the cleaned datasets to ensure the missing values are handled properly
patients_df.head()
# Out:
#    PATIENTID  GENDER ETHNICITY DECEASED DEATHCAUSECODE_1A DEATHLOCATIONCODE  \
# 0   10273711       1   Unknown        N               NaN               NaN
# 1   10275818       1         A        Y              K566                 4
# 2   10276182       1         A        Y              J189                 1
# 3   10277943       1         A        N               NaN               NaN
# 4   10279280       1         A        Y               C19                 4
#
#   VITALSTATUS VITALSTATUSDATE
# 0           A      2022-05-07
# 1           D      2021-10-20
# 2           D      2020-07-18
# 3           A      2022-05-07
# 4           D      2022-07-31

# %%
diagnosis_df.head()
# Out:
#    PATIENTID DIAGNOSISDATEBEST  SITE_ICD10_O2_3CHAR T_BEST N_BEST M_BEST  \
# 0   10300617         2/11/2019  C50 (Breast Cancer)      2      0     1b
# 1   10300637          5/6/2018  C50 (Breast Cancer)      2      0      0
# 2   10300641         26/1/2019  C50 (Breast Cancer)     1c      0      0
# 3   10300713         9/12/2017  C50 (Breast Cancer)      2      0      0
# 4   10300729         21/7/2019  C50 (Breast Cancer)      3      1      0
#
#   STAGE_BEST GRADE  AGE ER_STATUS PR_STATUS HER2_STATUS       QUINTILE_2019  \
# 0         3A    G3   46         P         P           N                   2
# 1          ?    G1   87         P       NaN           N                   4
# 2         1A    G2   87       NaN       NaN         NaN   1 - most deprived
# 3         2A    G2   74         U       NaN           N  5 - least deprived
# 4         2B    G3   71       NaN       NaN           P                   3
#
# ...

# %%
treatment_df.head()
# Out:
#    ENCORE_PATIENT_ID  HEIGHT_AT_START_OF_REGIMEN  WEIGHT_AT_START_OF_REGIMEN  \
# 0           10282626                    1.600000                   73.760354
# 1           10291762                    1.530000                   46.950000
# 2           10292545                    1.795778                   72.200000
# 3           10293472                    1.640000                   67.200000
# 4           10297710                    1.570000                  102.000000
#
#   DATE_DECISION_TO_TREAT START_DATE_OF_REGIMEN CLINICAL_TRIAL CHEMO_RADIATION  \
# 0             2022-12-05            2017-09-18            NaN             NaN
# 1             2022-12-05            2020-08-03            NaN             NaN
# 2             2022-12-05            2017-09-12            NaN               N
# 3             2022-12-05            2017-08-25            NaN               N
# 4             2016-02-07            2016-08-08              2               N
#
#             BENCHMARK_GROUP
# ...

# %%
# Group by patient and treatment regimen to identify first and second treatment regimens
# We will sort by PATIENTID and START_DATE_OF_REGIMEN to track treatment transitions
treatment_df['START_DATE_OF_REGIMEN'] = pd.to_datetime(treatment_df['START_DATE_OF_REGIMEN'], errors='coerce')

# Sort by patient ID and START_DATE_OF_REGIMEN to identify transitions
treatment_df_sorted = treatment_df.sort_values(by=['ENCORE_PATIENT_ID', 'START_DATE_OF_REGIMEN'])

# Identify first and second treatments for each patient
treatment_df_sorted['FIRST_TREATMENT'] = treatment_df_sorted.groupby('ENCORE_PATIENT_ID')['BENCHMARK_GROUP'].transform('first')
treatment_df_sorted['SECOND_TREATMENT'] = treatment_df_sorted.groupby('ENCORE_PATIENT_ID')['BENCHMARK_GROUP'].transform('nth', n=1)

# Count the most common first to second treatment transitions
treatment_transitions = treatment_df_sorted[['FIRST_TREATMENT', 'SECOND_TREATMENT']].value_counts().reset_index(name='Transition Count')

# Display the most common transitions
treatment_transitions.head()
# Out:
#                                      FIRST_TREATMENT  \
# 0                                                FEC
# 1       CYCLOPHOSPHAMIDE + EPIRUBICIN + FLUOROURACIL
# 2  CYCLOPHOSPHAMIDE + DOCETAXEL + EPIRUBICIN + FL...
# 3                                         PACLITAXEL
# 4                                                 EC
#
#                        SECOND_TREATMENT  Transition Count
# 0                             DOCETAXEL              8302
# 1                           TRASTUZUMAB              7732
# 2                             DOCETAXEL              7015
# 3                            PACLITAXEL              6718
# 4  DOCETAXEL + PERTUZUMAB + TRASTUZUMAB              5066

# %%
# Merging the relevant datasets (Patients, Diagnosis, and Treatment) for cohort comparison
# First, merge the Treatment dataset with Diagnosis and Patients to get the necessary columns for comparison

# Merge Patients with Diagnosis dataset on PATIENTID
merged_df = pd.merge(treatment_df_sorted[['ENCORE_PATIENT_ID', 'FIRST_TREATMENT', 'SECOND_TREATMENT']],
                     diagnosis_df[['PATIENTID', 'AGE', 'STAGE_BEST', 'GRADE']],
                     left_on='ENCORE_PATIENT_ID', right_on='PATIENTID', how='inner')

# Merge with the Patients dataset to get additional columns like gender
merged_df = pd.merge(merged_df, patients_df[['PATIENTID', 'GENDER', 'ETHNICITY', 'VITALSTATUS', 'VITALSTATUSDATE']],
                     left_on='ENCORE_PATIENT_ID', right_on='PATIENTID', how='inner')

# Now, we will sample Cohort 1 (most common treatment transition) and Cohort 2 (second most common transition)
cohort_1 = merged_df[merged_df['FIRST_TREATMENT'] == treatment_transitions.iloc[0]['FIRST_TREATMENT']]
cohort_2 = merged_df[merged_df['FIRST_TREATMENT'] == treatment_transitions.iloc[1]['FIRST_TREATMENT']]

# Sampling based on age and tumor stage to ensure comparability
# For simplicity, let's assume we sample a balanced number of patients from both cohorts based on age and stage.

cohort_1_sampled = cohort_1[(cohort_1['AGE'] >= cohort_1['AGE'].quantile(0.25)) & (cohort_1['AGE'] <= cohort_1['AGE'].quantile(0.75))]
cohort_2_sampled = cohort_2[(cohort_2['AGE'] >= cohort_2['AGE'].quantile(0.25)) & (cohort_2['AGE'] <= cohort_2['AGE'].quantile(0.75))]

# Now, let's ensure the sample sizes are balanced
cohort_1_sampled = cohort_1_sampled.sample(min(len(cohort_1_sampled), len(cohort_2_sampled)))
cohort_2_sampled = cohort_2_sampled.sample(min(len(cohort_1_sampled), len(cohort_2_sampled)))

# Display the first few rows of each cohort sample
cohort_1_sampled.head()
# Out:
#        ENCORE_PATIENT_ID FIRST_TREATMENT SECOND_TREATMENT  PATIENTID_x  AGE  \
# 45963           40121538             FEC        DOCETAXEL     40121538   69
# 37428           40115621             FEC        DOCETAXEL     40115621   54
# 37903           40115971             FEC        DOCETAXEL     40115971   61
# 43244           40119675             FEC        DOCETAXEL     40119675   57
# 43626           40119941             FEC        DOCETAXEL     40119941   52
#
#       STAGE_BEST GRADE  PATIENTID_y  GENDER ETHNICITY VITALSTATUS  \
# 45963         2A    G1     40121538       2         A           A
# 37428         1A    G2     40115621       2         A           A
# 37903         1A    G3     40115971       2         A           A
# 43244         1A    G1     40119675       2         A           A
# 43626         3A    G3     40119941       2         C           A
#
#       VITALSTATUSDATE
# 45963      2022-05-07
# 37428      2022-05-07
# 37903      2022-05-07
# ...

# %%
cohort_2_sampled.head()
# Out:
#        ENCORE_PATIENT_ID                               FIRST_TREATMENT  \
# 30592           40110982  CYCLOPHOSPHAMIDE + EPIRUBICIN + FLUOROURACIL
# 33672           40113102  CYCLOPHOSPHAMIDE + EPIRUBICIN + FLUOROURACIL
# 34824           40113863  CYCLOPHOSPHAMIDE + EPIRUBICIN + FLUOROURACIL
# 24809           40105449  CYCLOPHOSPHAMIDE + EPIRUBICIN + FLUOROURACIL
# 36091           40114708  CYCLOPHOSPHAMIDE + EPIRUBICIN + FLUOROURACIL
#
#       SECOND_TREATMENT  PATIENTID_x  AGE STAGE_BEST GRADE  PATIENTID_y  \
# 30592      TRASTUZUMAB     40110982   53         2A    G2     40110982
# 33672      TRASTUZUMAB     40113102   68         2A    G2     40113102
# 34824      TRASTUZUMAB     40113863   65         2A    G3     40113863
# 24809              NaN     40105449   56         2B    G2     40105449
# 36091      TRASTUZUMAB     40114708   57         1A    G3     40114708
#
#        GENDER ETHNICITY VITALSTATUS VITALSTATUSDATE
# 30592       2         A           D      2018-04-17
# ...

# %%
# First, we need to ensure that all date columns are in the correct format
merged_df['DIAGNOSISDATEBEST'] = pd.to_datetime(merged_df['DIAGNOSISDATEBEST'], errors='coerce')
merged_df['VITALSTATUSDATE'] = pd.to_datetime(merged_df['VITALSTATUSDATE'], errors='coerce')

# Calculate survival months: If the patient is deceased, use the VITALSTATUSDATE, else use today's date
merged_df['SURVIVAL_MONTHS'] = merged_df.apply(
    lambda row: (row['VITALSTATUSDATE'] - row['DIAGNOSISDATEBEST']).days / 30 if row['VITALSTATUS'] == 'D' 
    else (pd.to_datetime('today') - row['DIAGNOSISDATEBEST']).days / 30, axis=1)

# Now, calculate the survival months for each cohort
cohort_1_sampled['SURVIVAL_MONTHS'] = cohort_1_sampled.apply(
    lambda row: (row['VITALSTATUSDATE'] - row['DIAGNOSISDATEBEST']).days / 30 if row['VITALSTATUS'] == 'D'
    else (pd.to_datetime('today') - row['DIAGNOSISDATEBEST']).days / 30, axis=1)

cohort_2_sampled['SURVIVAL_MONTHS'] = cohort_2_sampled.apply(
    lambda row: (row['VITALSTATUSDATE'] - row['DIAGNOSISDATEBEST']).days / 30 if row['VITALSTATUS'] == 'D'
    else (pd.to_datetime('today') - row['DIAGNOSISDATEBEST']).days / 30, axis=1)

# Now, let's check the survival months for both cohorts
cohort_1_sampled[['ENCORE_PATIENT_ID', 'SURVIVAL_MONTHS']].head(), cohort_2_sampled[['ENCORE_PATIENT_ID', 'SURVIVAL_MONTHS']].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/envs/mlunit/lib/python3.9/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File /opt/miniconda3/envs/mlunit/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/miniconda3/envs/mlunit/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DIAGNOSISDATEBEST'
#
# ...

# %%
# Check the column names to identify any potential mismatches
merged_df.columns
# Out:
# Index(['ENCORE_PATIENT_ID', 'FIRST_TREATMENT', 'SECOND_TREATMENT',
#        'PATIENTID_x', 'AGE', 'STAGE_BEST', 'GRADE', 'PATIENTID_y', 'GENDER',
#        'ETHNICITY', 'VITALSTATUS', 'VITALSTATUSDATE'],
#       dtype='object')

# %%
# Merge the datasets again ensuring DIAGNOSISDATEBEST is included
merged_df = pd.merge(treatment_df_sorted[['ENCORE_PATIENT_ID', 'FIRST_TREATMENT', 'SECOND_TREATMENT']],
                     diagnosis_df[['PATIENTID', 'DIAGNOSISDATEBEST', 'AGE', 'STAGE_BEST', 'GRADE']],
                     left_on='ENCORE_PATIENT_ID', right_on='PATIENTID', how='inner')

merged_df = pd.merge(merged_df, patients_df[['PATIENTID', 'GENDER', 'ETHNICITY', 'VITALSTATUS', 'VITALSTATUSDATE']],
                     left_on='ENCORE_PATIENT_ID', right_on='PATIENTID', how='inner')

# Now we can calculate the survival months again
merged_df['DIAGNOSISDATEBEST'] = pd.to_datetime(merged_df['DIAGNOSISDATEBEST'], errors='coerce')
merged_df['VITALSTATUSDATE'] = pd.to_datetime(merged_df['VITALSTATUSDATE'], errors='coerce')

# Calculate survival months: If the patient is deceased, use the VITALSTATUSDATE, else use today's date
merged_df['SURVIVAL_MONTHS'] = merged_df.apply(
    lambda row: (row['VITALSTATUSDATE'] - row['DIAGNOSISDATEBEST']).days / 30 if row['VITALSTATUS'] == 'D' 
    else (pd.to_datetime('today') - row['DIAGNOSISDATEBEST']).days / 30, axis=1)

# Now, calculate the survival months for each cohort
cohort_1_sampled['SURVIVAL_MONTHS'] = cohort_1_sampled.apply(
    lambda row: (row['VITALSTATUSDATE'] - row['DIAGNOSISDATEBEST']).days / 30 if row['VITALSTATUS'] == 'D'
    else (pd.to_datetime('today') - row['DIAGNOSISDATEBEST']).days / 30, axis=1)

cohort_2_sampled['SURVIVAL_MONTHS'] = cohort_2_sampled.apply(
    lambda row: (row['VITALSTATUSDATE'] - row['DIAGNOSISDATEBEST']).days / 30 if row['VITALSTATUS'] == 'D'
    else (pd.to_datetime('today') - row['DIAGNOSISDATEBEST']).days / 30, axis=1)

# Display the survival months for both cohorts
cohort_1_sampled[['ENCORE_PATIENT_ID', 'SURVIVAL_MONTHS']].head(), cohort_2_sampled[['ENCORE_PATIENT_ID', 'SURVIVAL_MONTHS']].head()
# Out:
# /var/folders/ss/lyb76ms57n90jdlgjkqwn2340000gn/T/ipykernel_60312/2067708829.py:10: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   merged_df['DIAGNOSISDATEBEST'] = pd.to_datetime(merged_df['DIAGNOSISDATEBEST'], errors='coerce')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/envs/mlunit/lib/python3.9/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File /opt/miniconda3/envs/mlunit/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
# Ensure that DIAGNOSISDATEBEST is included in the cohort datasets during the merge process
cohort_1_merged = pd.merge(cohort_1_sampled, diagnosis_df[['PATIENTID', 'DIAGNOSISDATEBEST']], left_on='ENCORE_PATIENT_ID', right_on='PATIENTID', how='left')
cohort_2_merged = pd.merge(cohort_2_sampled, diagnosis_df[['PATIENTID', 'DIAGNOSISDATEBEST']], left_on='ENCORE_PATIENT_ID', right_on='PATIENTID', how='left')

# Now calculate survival months for each cohort
cohort_1_merged['DIAGNOSISDATEBEST'] = pd.to_datetime(cohort_1_merged['DIAGNOSISDATEBEST'], errors='coerce')
cohort_1_merged['VITALSTATUSDATE'] = pd.to_datetime(cohort_1_merged['VITALSTATUSDATE'], errors='coerce')

cohort_1_merged['SURVIVAL_MONTHS'] = cohort_1_merged.apply(
    lambda row: (row['VITALSTATUSDATE'] - row['DIAGNOSISDATEBEST']).days / 30 if row['VITALSTATUS'] == 'D'
    else (pd.to_datetime('today') - row['DIAGNOSISDATEBEST']).days / 30, axis=1)

cohort_2_merged['DIAGNOSISDATEBEST'] = pd.to_datetime(cohort_2_merged['DIAGNOSISDATEBEST'], errors='coerce')
cohort_2_merged['VITALSTATUSDATE'] = pd.to_datetime(cohort_2_merged['VITALSTATUSDATE'], errors='coerce')

cohort_2_merged['SURVIVAL_MONTHS'] = cohort_2_merged.apply(
    lambda row: (row['VITALSTATUSDATE'] - row['DIAGNOSISDATEBEST']).days / 30 if row['VITALSTATUS'] == 'D'
    else (pd.to_datetime('today') - row['DIAGNOSISDATEBEST']).days / 30, axis=1)

# Now, display the survival months for both cohorts
cohort_1_merged[['ENCORE_PATIENT_ID', 'SURVIVAL_MONTHS']].head()
# Out:
# /var/folders/ss/lyb76ms57n90jdlgjkqwn2340000gn/T/ipykernel_60312/2958654728.py:6: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cohort_1_merged['DIAGNOSISDATEBEST'] = pd.to_datetime(cohort_1_merged['DIAGNOSISDATEBEST'], errors='coerce')
# /var/folders/ss/lyb76ms57n90jdlgjkqwn2340000gn/T/ipykernel_60312/2958654728.py:13: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cohort_2_merged['DIAGNOSISDATEBEST'] = pd.to_datetime(cohort_2_merged['DIAGNOSISDATEBEST'], errors='coerce')
#    ENCORE_PATIENT_ID  SURVIVAL_MONTHS
# 0           40121538        75.200000
# 1           40115621       100.866667
# 2           40115971        98.833333
# 3           40119675        76.900000
# ...

# %%
cohort_2_merged[['ENCORE_PATIENT_ID', 'SURVIVAL_MONTHS']].head()
# Out:
#    ENCORE_PATIENT_ID  SURVIVAL_MONTHS
# 0           40110982        -0.466667
# 1           40113102        65.466667
# 2           40113863        99.300000
# 3           40105449        98.233333
# 4           40114708        95.633333

# %%
from scipy.stats import ttest_ind

# Perform a t-test to compare the survival months between the two cohorts
cohort_1_survival = cohort_1_merged['SURVIVAL_MONTHS']
cohort_2_survival = cohort_2_merged['SURVIVAL_MONTHS']

# Conduct the t-test
t_stat, p_value = ttest_ind(cohort_1_survival, cohort_2_survival)

t_stat, p_value
# Out:
# (0.6229005166492855, 0.5333641902529798)

# %%
import matplotlib.pyplot as plt

# Plotting histograms for the survival months of both cohorts
plt.figure(figsize=(12, 6))

# Histogram for Cohort 1
plt.subplot(1, 2, 1)
plt.hist(cohort_1_merged['SURVIVAL_MONTHS'], bins=20, color='skyblue', edgecolor='black')
plt.title('Survival Months - Cohort 1 (FEC -> DOCETAXEL)')
plt.xlabel('Survival Months')
plt.ylabel('Frequency')

# Histogram for Cohort 2
plt.subplot(1, 2, 2)
plt.hist(cohort_2_merged['SURVIVAL_MONTHS'], bins=20, color='salmon', edgecolor='black')
plt.title('Survival Months - Cohort 2 (CYCLOPHOSPHAMIDE -> TRASTUZUMAB)')
plt.xlabel('Survival Months')
plt.ylabel('Frequency')

# Show the plots
plt.tight_layout()
plt.show()

# Plotting box plots to compare the two cohorts' survival months
plt.figure(figsize=(8, 6))
plt.boxplot([cohort_1_merged['SURVIVAL_MONTHS'], cohort_2_merged['SURVIVAL_MONTHS']], 
            labels=['Cohort 1', 'Cohort 2'], 
            patch_artist=True, 
            boxprops=dict(facecolor='lightblue', color='black'),
            whiskerprops=dict(color='black'),
            flierprops=dict(markerfacecolor='red', marker='o', markersize=6))

plt.title('Comparison of Survival Months Between Cohorts')
plt.ylabel('Survival Months')
plt.show()
